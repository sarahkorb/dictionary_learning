# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahkorb/dictionary_learning/blob/main/CRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sarahkorb/dictionary_learning.git
# Out:
# Cloning into 'dictionary_learning'...
# remote: Enumerating objects: 887, done.
# remote: Counting objects: 100% (480/480), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 887 (delta 385), reused 415 (delta 347), pack-reused 407 (from 1)
# Receiving objects: 100% (887/887), 419.26 KiB | 2.72 MiB/s, done.
# Resolving deltas: 100% (577/577), done.

# %%
# %cd dictionary_learning
# Out:
# /content/dictionary_learning

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
